# %%
print("masum")
# Out:
# masum

# %%
a = 20
print(a)
# Out:
# 20

# %%
a = 20
b = 20
print(a+b)
# Out:
# 40

# %%
name1 = "Masum"
name1
# Out:
# 'Masum'

# %%
a = 100

# %%
a
# Out:
# 100

# %%
a = 40
a1 = 30

print(id(a))
print(id(a1))
# Out:
# 140721521704600
# 140721521704280

# %%
a = "50"
a = int(a)
print(a)
print(type(a))
# Out:
# 50
# <class 'int'>

# %%
a = 14
if a < 100:
    print("Good")
    if a < 20:
        print("2")
elif a < 20:
    print("20")
else:
    print("not good")
# Out:
# Good
# 2

# %%
for i in range(10):
    print("Masum Billah")
# Out:
# Masum Billah
# Masum Billah
# Masum Billah
# Masum Billah
# Masum Billah
# Masum Billah
# Masum Billah
# Masum Billah
# Masum Billah
# Masum Billah

# %%
i = 1
while i<6:
    print("Masum")
    i = i+1
# Out:
# Masum
# Masum
# Masum
# Masum
# Masum

# %%
x = ["masum", "abdullah", "rahman",1]

for i in x:
    print(i)
# Out:
# masum
# abdullah
# rahman
# 1

# %%
for i in range(3,6):
    print("Masum Billah")
# Out:
# Masum Billah
# Masum Billah
# Masum Billah

# %%
for i in range(1,3):
    print("From Outer Loop")

    for j in range(1,4):
        print("i = ", i, "and", "j = ", j)
# Out:
# From Outer Loop
# i =  1 and j =  1
# i =  1 and j =  2
# i =  1 and j =  3
# From Outer Loop
# i =  2 and j =  1
# i =  2 and j =  2
# i =  2 and j =  3

# %%
for i in range(1,3):
    print("Please check Nuber")
    for j in range(1,4):
        print("Show your Number")
# Out:
# Please check Nuber
# Show your Number
# Show your Number
# Show your Number
# Please check Nuber
# Show your Number
# Show your Number
# Show your Number

# %%
for i in range(1, 11):
    if i ==5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
name = ["shahidullah", "masum", "bappy"]

for i in name:
    if i == "masum":
        break
        print(i)

# %%
for i in range(1,11):
    pass

# %%
if 202==202:
    pass

# %%
print("masum")
# Out:
# masum

# %%
print("masum")
# Out:
# masum

# %%
print("masum")
# Out:
# masum

# %%
print("masum")
# Out:
# masum
