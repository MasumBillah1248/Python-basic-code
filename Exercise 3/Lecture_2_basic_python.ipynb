# %%
print("masum")
# Out:
# masum

# %% [markdown]
# # Conditional Statement

# %%
email = input("Enter your email: ")
password = input("Enter your password: ")

actual_email = "masum.clippingdealer@gmail.com"
actual_password = "Masum@###"

if email == actual_email and actual_password == password:
     print("Login Successfull!")
elif email == actual_email and password != actual_password:
    print("Please try agian")
    password = input("Enter your passowrd again: ")
    if password == actual_password:
        print("Success!")
    else:
        print("Wrong")
        
        

 

else:
     print("Invalid Credentials!")
# Out:
# Please try agian
# Success!

# %%
num1 = int(input("Enter the First Number: "))
num2 = int(input("Enter the Second Number: "))
num3 = int(input("Enter the Third Number: "))

print(num1, num2, num3)

# %%
print("Masum")
# Out:
# Masum

# %%
print("mas")
# Out:
# mas

# %%
menu = input("""

Hi there! Welcome to ATM 
please choose,
             
1. Enter 1 for Pin change
2. Enter 2 for Balance check
3. Enter 3 for Withdraw
4. Enter 4 for Deposit
5. Enter 5 for Exit
             
             
            

""")
print(menu)

if menu == "1":
    print("Pin Change")

elif menu == "2":
    print("Balance check")

elif menu == "3":
    print("Withdraw")

elif menu == "4":
    print("Deposit")

else:
    print("Exit")
# Out:
# 3
# Withdraw

# %%
import math

print(math.sin(300))
# Out:
# -0.9997558399011495

# %%
math.sqrt(33)
# Out:
# 5.744562646538029

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import random

print(random.randint(1,200))
# Out:
# 120

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2025-11-04 16:53:07.132916

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 6.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.0 MB 9.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.9/11.0 MB 9.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.1/11.0 MB 4.2 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.0 MB 3.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/11.0 MB 4.0 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.0 MB 4.9 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 5.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 5.2 MB/s  0:00:02
# ...

# %%
# !pip install fastapi
# Out:
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 10.2 MB/s  0:00:00
# ...
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# ...
#
#    ------- --------------------------------  2/11 [idna]
#    -------------- -------------------------  4/11 [annotated-doc]
#    --------------------- ------------------  6/11 [pydantic-core]
#    ------------------------- --------------  7/11 [anyio]
#    ------------------------- --------------  7/11 [anyio]
#    ------------------------- --------------  7/11 [anyio]
#    ------------------------- --------------  7/11 [anyio]
#    ----------------------------- ----------  8/11 [starlette]
#    ----------------------------- ----------  8/11 [starlette]
#    ----------------------------- ----------  8/11 [starlette]
#    ----------------------------- ----------  8/11 [starlette]
# ...

# %%
import fastapi

# %%
print("Masum")
# Out:
# Masum

# %%
from typing import Union

from fastapi import FastAPI

app = FastAPI()


@app.get("/")
def read_root():
    return {"Hello": "World"}
