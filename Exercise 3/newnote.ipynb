# %% [markdown]
# #Start Python Programming

# %%
print("Hello")
# Out:
# Hello

# %%
print("masum",12,233,True,sep="__")
# Out:
# masum__12__233__True

# %%
print("masum")
# Out:
# masum

# %%
print("123",end="")
print("Masum",end="")
print("Billah")
# Out:
# 123MasumBillah

# %%
type("M")
# Out:
# str

# %%
print(type(1))
print(type(True))
print(type([]))
print(type(()))
print(type({}))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>

# %%
type(3j)
# Out:
# complex

# %%
type(3+3j)
# Out:
# complex

# %%
print("Masum Billah")
# Out:
# Masum Billah

# %%
input()
# Out:
# Masum Billah
# 'Masum Billah'

# %%
var = 23

# %%
var = input()
# Out:
# 2.20

# %%
print(var)
# Out:
# 2.20

# %%
print(type(var))
# Out:
# <class 'str'>

# %%
var1 = float(input())
# Out:
# 30.

# %%
print(type(var1))
# Out:
# <class 'float'>

# %%
a = str(input("Enter First number:"))
b = str(input("Enter Second Nuber: "))

result = a+b
print(result)


print(type(a))
print(type(b))
# Out:
# Enter First number:11
# Enter Second Nuber: 1df
# 111df
# <class 'str'>
# <class 'str'>

# %%
a = 120+20.2
print(a)
print(type(a))
# Out:
# 140.2
# <class 'float'>

# %%
m = 4 + "4"
print(m)
print(type(m))|
# Out:
#   File "/tmp/ipython-input-893209376.py", line 3
#     print(type(m))|
#                    ^
# SyntaxError: invalid syntax

# %%
a = 10.5
b = 1.5e2
c = 1.5e-3
print(a)
print(b)
print(c)
# Out:
# 10.5
# 150.0
# 0.0015

# %%
unicode = u"\U0001f600\U0001F606\U0001F921\U0001F923"
print(unicode)
# Out:
# 😀😆🤡🤣

# %%
print("Masum")
# Out:
# Masum

# %% [markdown]
# #Operator

# %% [markdown]
# #Masum

# %%
print(0 and 1)
# Out:
# 0

# %%
print( 0 or 1)
# Out:
# 1

# %%
print(not o))
# Out:
#   File "/tmp/ipython-input-3112345691.py", line 1
#     print(not o))
#                 ^
# SyntaxError: unmatched ')'

# %%
print(not 0)
# Out:
# True

# %%
print( not 1)
# Out:
# False

# %%
print("Hello")
# Out:
# Hello
